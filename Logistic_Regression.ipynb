# %% [markdown]
# <a href="https://colab.research.google.com/github/Prince-techh/ML_learning/blob/main1/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/placement (1).csv")

# %%
df = df.iloc[:,1:]
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_test
# Out:
#     cgpa     iq
# 56   6.1   65.0
# 57   6.5  130.0
# 82   6.5   37.0
# 91   7.5  158.0
# 11   6.9  138.0
# 81   5.4  107.0
# 36   5.7  140.0
# 33   6.0  149.0
# 13   6.4  116.0
# 86   5.1  128.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.99233396,  0.41626505],
#        [ 0.70880997, -0.0333012 ],
#        [-2.09807752,  2.71404812],
#        [-0.14176199,  1.04066262],
#        [-1.41761994,  1.88984332],
#        [-1.33256275, -2.05634934],
#        [ 0.19846679, -0.28306023],
#        [ 0.1134096 , -1.08228913],
#        [-0.90727676,  1.78993971],
#        [ 0.70880997, -0.30803614],
#        [ 0.45363838, -0.857506  ],
#        [ 0.79386717,  0.36631324],
#        [ 1.13409595, -0.20813252],
#        [ 0.87892436,  1.86486742],
#        [ 0.0283524 , -0.0083253 ],
#        [ 1.30421035, -1.58180719],
#        [-0.90727676, -1.58180719],
#        [ 0.96398156,  0.66602408],
#        [ 0.0283524 , -1.45692767],
#        [-0.65210517,  0.91578311],
#        [ 0.1134096 ,  0.79090359],
#        [-0.73716237, -1.45692767],
#        [-0.48199078,  0.26640963],
#        [ 1.81455353,  0.61607227],
#        [ 0.53869558, -0.10822891],
#        [-1.07739116, -1.80659031],
#        [-0.22681919,  0.46621685],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.1134096 , -1.48190357],
#        [ 0.45363838,  0.14153012],
#        [ 0.45363838, -2.18122886],
#        [ 1.30421035,  0.8408554 ],
#        [ 0.79386717,  0.34133734],
#        [-0.48199078, -0.43291565],
#        [-0.22681919,  0.39128915],
#        [ 0.0283524 ,  0.61607227],
#        [ 0.36858119, -0.20813252],
#        [-0.73716237,  0.09157831]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 56    0
# 57    1
# 82    1
# 91    1
# 11    1
# 81    0
# 36    0
# 33    0
# 13    1
# 86    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
